# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# Import the random module.
import random
# Import the API key.
from citipy import citipy
from config import weather_api_key

# %%
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
cities = []
for coordinate in lat_lngs:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    if city not in cities:
        cities.append(city)
len(cities)
# Out:
# 733

# %%
# Import the requests library.
import requests
import time
from datetime import datetime
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        #print(city_weather)
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_desc = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Description": city_desc,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | norrtalje
# Processing Record 2 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 3 of Set 1 | rikitea
# Processing Record 4 of Set 1 | cherskiy
# Processing Record 5 of Set 1 | laguna
# Processing Record 6 of Set 1 | ushuaia
# Processing Record 7 of Set 1 | hilo
# Processing Record 8 of Set 1 | santa maria
# Processing Record 9 of Set 1 | mataura
# Processing Record 10 of Set 1 | longyearbyen
# Processing Record 11 of Set 1 | clyde river
# Processing Record 12 of Set 1 | juba
# Processing Record 13 of Set 1 | shushenskoye
# Processing Record 14 of Set 1 | cape town
# Processing Record 15 of Set 1 | new norfolk
# Processing Record 16 of Set 1 | tiksi
# Processing Record 17 of Set 1 | salta
# Processing Record 18 of Set 1 | lavrentiya
# Processing Record 19 of Set 1 | treinta y tres
# Processing Record 20 of Set 1 | hermanus
# Processing Record 21 of Set 1 | bredasdorp
# Processing Record 22 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 23 of Set 1 | saskylakh
# Processing Record 24 of Set 1 | kavieng
# Processing Record 25 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 26 of Set 1 | lolua
# City not found. Skipping...
# Processing Record 27 of Set 1 | zunyi
# Processing Record 28 of Set 1 | ullapool
# Processing Record 29 of Set 1 | busselton
# Processing Record 30 of Set 1 | najran
# Processing Record 31 of Set 1 | hithadhoo
# Processing Record 32 of Set 1 | coari
# Processing Record 33 of Set 1 | kahului
# Processing Record 34 of Set 1 | okandja
# City not found. Skipping...
# Processing Record 35 of Set 1 | punta arenas
# Processing Record 36 of Set 1 | korla
# Processing Record 37 of Set 1 | nichinan
# Processing Record 38 of Set 1 | avarua
# Processing Record 39 of Set 1 | abha
# Processing Record 40 of Set 1 | ribeira grande
# Processing Record 41 of Set 1 | jamestown
# Processing Record 42 of Set 1 | mecca
# Processing Record 43 of Set 1 | elko
# Processing Record 44 of Set 1 | lebu
# Processing Record 45 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 46 of Set 1 | uarini
# Processing Record 47 of Set 1 | vaini
# Processing Record 48 of Set 1 | albany
# Processing Record 49 of Set 1 | hobart
# Processing Record 50 of Set 1 | spearfish
# Processing Record 1 of Set 2 | salcininkai
# Processing Record 2 of Set 2 | arcachon
# Processing Record 3 of Set 2 | koungou
# Processing Record 4 of Set 2 | zhuanghe
# Processing Record 5 of Set 2 | formoso do araguaia
# City not found. Skipping...
# Processing Record 6 of Set 2 | kapaa
# Processing Record 7 of Set 2 | kampong cham
# Processing Record 8 of Set 2 | sarangani
# Processing Record 9 of Set 2 | kalmunai
# Processing Record 10 of Set 2 | nome
# Processing Record 11 of Set 2 | balabac
# Processing Record 12 of Set 2 | codrington
# Processing Record 13 of Set 2 | yellowknife
# Processing Record 14 of Set 2 | progreso
# Processing Record 15 of Set 2 | bandarbeyla
# Processing Record 16 of Set 2 | vao
# Processing Record 17 of Set 2 | pangody
# Processing Record 18 of Set 2 | ostrovnoy
# Processing Record 19 of Set 2 | east london
# Processing Record 20 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 21 of Set 2 | mezica
# Processing Record 22 of Set 2 | luderitz
# Processing Record 23 of Set 2 | te anau
# Processing Record 24 of Set 2 | arraial do cabo
# Processing Record 25 of Set 2 | corrente
# Processing Record 26 of Set 2 | guerrero negro
# Processing Record 27 of Set 2 | upernavik
# Processing Record 28 of Set 2 | lerwick
# Processing Record 29 of Set 2 | byurakan
# Processing Record 30 of Set 2 | port lincoln
# Processing Record 31 of Set 2 | gainesville
# Processing Record 32 of Set 2 | tasiilaq
# Processing Record 33 of Set 2 | severo-kurilsk
# Processing Record 34 of Set 2 | katherine
# Processing Record 35 of Set 2 | fort nelson
# Processing Record 36 of Set 2 | bluff
# Processing Record 37 of Set 2 | kaitangata
# Processing Record 38 of Set 2 | castro
# Processing Record 39 of Set 2 | sayat
# Processing Record 40 of Set 2 | kigali
# Processing Record 41 of Set 2 | tabiauea
# City not found. Skipping...
# Processing Record 42 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 43 of Set 2 | nikolskoye
# Processing Record 44 of Set 2 | sao felix do xingu
# Processing Record 45 of Set 2 | southbridge
# Processing Record 46 of Set 2 | bengkulu
# Processing Record 47 of Set 2 | puerto ayora
# Processing Record 48 of Set 2 | georgetown
# Processing Record 49 of Set 2 | san quintin
# Processing Record 50 of Set 2 | asau
# Processing Record 1 of Set 3 | chuy
# Processing Record 2 of Set 3 | butaritari
# Processing Record 3 of Set 3 | faanui
# Processing Record 4 of Set 3 | high rock
# Processing Record 5 of Set 3 | saldanha
# Processing Record 6 of Set 3 | plettenberg bay
# Processing Record 7 of Set 3 | vostok
# Processing Record 8 of Set 3 | sidi ali
# Processing Record 9 of Set 3 | vestmannaeyjar
# Processing Record 10 of Set 3 | kalabo
# Processing Record 11 of Set 3 | dikson
# Processing Record 12 of Set 3 | khatanga
# Processing Record 13 of Set 3 | nabire
# Processing Record 14 of Set 3 | nanortalik
# Processing Record 15 of Set 3 | pitimbu
# Processing Record 16 of Set 3 | barrow
# Processing Record 17 of Set 3 | kurilsk
# Processing Record 18 of Set 3 | itarema
# Processing Record 19 of Set 3 | pangnirtung
# Processing Record 20 of Set 3 | maniitsoq
# Processing Record 21 of Set 3 | duluth
# Processing Record 22 of Set 3 | atuona
# Processing Record 23 of Set 3 | covasint
# Processing Record 24 of Set 3 | gualaquiza
# Processing Record 25 of Set 3 | copiapo
# Processing Record 26 of Set 3 | provideniya
# Processing Record 27 of Set 3 | palmer
# Processing Record 28 of Set 3 | myre
# Processing Record 29 of Set 3 | thompson
# Processing Record 30 of Set 3 | xai-xai
# Processing Record 31 of Set 3 | bafq
# Processing Record 32 of Set 3 | yulin
# Processing Record 33 of Set 3 | broken hill
# Processing Record 34 of Set 3 | alekseyevsk
# Processing Record 35 of Set 3 | ponta do sol
# Processing Record 36 of Set 3 | hearst
# Processing Record 37 of Set 3 | brae
# Processing Record 38 of Set 3 | reading
# Processing Record 39 of Set 3 | atar
# Processing Record 40 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 41 of Set 3 | komsomolskiy
# Processing Record 42 of Set 3 | isla vista
# Processing Record 43 of Set 3 | wahiawa
# Processing Record 44 of Set 3 | san jose
# Processing Record 45 of Set 3 | dwarka
# Processing Record 46 of Set 3 | moerai
# Processing Record 47 of Set 3 | souillac
# Processing Record 48 of Set 3 | cibitoke
# Processing Record 49 of Set 3 | meyungs
# City not found. Skipping...
# Processing Record 50 of Set 3 | pacific grove
# Processing Record 1 of Set 4 | warqla
# City not found. Skipping...
# Processing Record 2 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 3 of Set 4 | atamanovka
# Processing Record 4 of Set 4 | mar del plata
# Processing Record 5 of Set 4 | kruisfontein
# Processing Record 6 of Set 4 | rongcheng
# Processing Record 7 of Set 4 | ushtobe
# Processing Record 8 of Set 4 | bathsheba
# Processing Record 9 of Set 4 | anadyr
# Processing Record 10 of Set 4 | alugan
# Processing Record 11 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 12 of Set 4 | sosnovo-ozerskoye
# Processing Record 13 of Set 4 | rawson
# Processing Record 14 of Set 4 | lake havasu city
# Processing Record 15 of Set 4 | tuktoyaktuk
# Processing Record 16 of Set 4 | kodiak
# Processing Record 17 of Set 4 | mangochi
# Processing Record 18 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 19 of Set 4 | diego de almagro
# Processing Record 20 of Set 4 | yatou
# Processing Record 21 of Set 4 | kadykchan
# City not found. Skipping...
# Processing Record 22 of Set 4 | christchurch
# Processing Record 23 of Set 4 | velasco ibarra
# Processing Record 24 of Set 4 | ixtepec
# Processing Record 25 of Set 4 | nisia floresta
# Processing Record 26 of Set 4 | tammisaari
# Processing Record 27 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 28 of Set 4 | torbay
# Processing Record 29 of Set 4 | ayr
# Processing Record 30 of Set 4 | boa vista
# Processing Record 31 of Set 4 | port elizabeth
# Processing Record 32 of Set 4 | qeshm
# Processing Record 33 of Set 4 | quesnel
# Processing Record 34 of Set 4 | san rafael
# Processing Record 35 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 36 of Set 4 | katsuura
# Processing Record 37 of Set 4 | pevek
# Processing Record 38 of Set 4 | walvis bay
# Processing Record 39 of Set 4 | mandera
# Processing Record 40 of Set 4 | vagur
# Processing Record 41 of Set 4 | qaanaaq
# Processing Record 42 of Set 4 | ancud
# Processing Record 43 of Set 4 | qaqortoq
# Processing Record 44 of Set 4 | ingham
# Processing Record 45 of Set 4 | port augusta
# Processing Record 46 of Set 4 | palauig
# Processing Record 47 of Set 4 | okhotsk
# Processing Record 48 of Set 4 | carballo
# Processing Record 49 of Set 4 | sambava
# Processing Record 50 of Set 4 | bethel
# Processing Record 1 of Set 5 | amapa
# Processing Record 2 of Set 5 | waitati
# Processing Record 3 of Set 5 | puerto cabezas
# Processing Record 4 of Set 5 | odesskoye
# Processing Record 5 of Set 5 | auki
# Processing Record 6 of Set 5 | kalamoton
# City not found. Skipping...
# Processing Record 7 of Set 5 | jackson
# Processing Record 8 of Set 5 | kelvington
# Processing Record 9 of Set 5 | aitape
# Processing Record 10 of Set 5 | hobro
# Processing Record 11 of Set 5 | carnarvon
# Processing Record 12 of Set 5 | bartlett
# Processing Record 13 of Set 5 | bilma
# Processing Record 14 of Set 5 | biak
# Processing Record 15 of Set 5 | sabha
# Processing Record 16 of Set 5 | arkadak
# Processing Record 17 of Set 5 | lasa
# Processing Record 18 of Set 5 | clearlake
# Processing Record 19 of Set 5 | ilulissat
# Processing Record 20 of Set 5 | sataua
# City not found. Skipping...
# Processing Record 21 of Set 5 | victoria
# Processing Record 22 of Set 5 | cardston
# Processing Record 23 of Set 5 | at-bashi
# Processing Record 24 of Set 5 | langsa
# Processing Record 25 of Set 5 | palana
# Processing Record 26 of Set 5 | anuradhapura
# Processing Record 27 of Set 5 | maragogi
# Processing Record 28 of Set 5 | borzya
# Processing Record 29 of Set 5 | portland
# Processing Record 30 of Set 5 | talnakh
# Processing Record 31 of Set 5 | mtwara
# Processing Record 32 of Set 5 | north bend
# Processing Record 33 of Set 5 | comodoro rivadavia
# Processing Record 34 of Set 5 | louga
# Processing Record 35 of Set 5 | maicao
# Processing Record 36 of Set 5 | tazovskiy
# Processing Record 37 of Set 5 | osa
# Processing Record 38 of Set 5 | rio grande
# Processing Record 39 of Set 5 | moron
# Processing Record 40 of Set 5 | sharjah
# Processing Record 41 of Set 5 | samsun
# Processing Record 42 of Set 5 | enumclaw
# Processing Record 43 of Set 5 | ubinskoye
# Processing Record 44 of Set 5 | hobyo
# Processing Record 45 of Set 5 | malwan
# City not found. Skipping...
# Processing Record 46 of Set 5 | sinnamary
# Processing Record 47 of Set 5 | chokurdakh
# Processing Record 48 of Set 5 | inhambane
# Processing Record 49 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 50 of Set 5 | puerto colombia
# Processing Record 1 of Set 6 | cayenne
# Processing Record 2 of Set 6 | isangel
# Processing Record 3 of Set 6 | husavik
# Processing Record 4 of Set 6 | college
# Processing Record 5 of Set 6 | leningradskiy
# Processing Record 6 of Set 6 | isiro
# Processing Record 7 of Set 6 | tarudant
# City not found. Skipping...
# Processing Record 8 of Set 6 | beringovskiy
# Processing Record 9 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 10 of Set 6 | bireun
# Processing Record 11 of Set 6 | marawi
# Processing Record 12 of Set 6 | peringat
# Processing Record 13 of Set 6 | saint george
# Processing Record 14 of Set 6 | bereda
# Processing Record 15 of Set 6 | coquimbo
# Processing Record 16 of Set 6 | iqaluit
# Processing Record 17 of Set 6 | mayumba
# Processing Record 18 of Set 6 | kavaratti
# Processing Record 19 of Set 6 | port-gentil
# Processing Record 20 of Set 6 | aswan
# Processing Record 21 of Set 6 | tuatapere
# Processing Record 22 of Set 6 | champasak
# Processing Record 23 of Set 6 | volchikha
# Processing Record 24 of Set 6 | ishcherskaya
# Processing Record 25 of Set 6 | gat
# Processing Record 26 of Set 6 | abu zabad
# Processing Record 27 of Set 6 | bafoulabe
# Processing Record 28 of Set 6 | rio gallegos
# Processing Record 29 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 30 of Set 6 | utiroa
# City not found. Skipping...
# Processing Record 31 of Set 6 | macenta
# Processing Record 32 of Set 6 | zelenoborsk
# Processing Record 33 of Set 6 | port alfred
# Processing Record 34 of Set 6 | westport
# Processing Record 35 of Set 6 | det udom
# Processing Record 36 of Set 6 | saint-augustin
# Processing Record 37 of Set 6 | sokol
# Processing Record 38 of Set 6 | bonavista
# Processing Record 39 of Set 6 | riyadh
# Processing Record 40 of Set 6 | iwanai
# Processing Record 41 of Set 6 | san cristobal
# Processing Record 42 of Set 6 | tilichiki
# Processing Record 43 of Set 6 | cabo san lucas
# Processing Record 44 of Set 6 | cidreira
# Processing Record 45 of Set 6 | deputatskiy
# Processing Record 46 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 47 of Set 6 | hofn
# Processing Record 48 of Set 6 | richards bay
# Processing Record 49 of Set 6 | kununurra
# Processing Record 50 of Set 6 | shibganj
# Processing Record 1 of Set 7 | ust-ilimsk
# Processing Record 2 of Set 7 | guhagar
# Processing Record 3 of Set 7 | winnemucca
# Processing Record 4 of Set 7 | fortuna
# Processing Record 5 of Set 7 | carupano
# Processing Record 6 of Set 7 | esperance
# Processing Record 7 of Set 7 | sakakah
# Processing Record 8 of Set 7 | kirakira
# Processing Record 9 of Set 7 | neiafu
# Processing Record 10 of Set 7 | yichun
# Processing Record 11 of Set 7 | muisne
# Processing Record 12 of Set 7 | mangan
# Processing Record 13 of Set 7 | marsa matruh
# Processing Record 14 of Set 7 | san luis
# Processing Record 15 of Set 7 | northam
# Processing Record 16 of Set 7 | roald
# Processing Record 17 of Set 7 | alyangula
# Processing Record 18 of Set 7 | jabiru
# City not found. Skipping...
# Processing Record 19 of Set 7 | koslan
# Processing Record 20 of Set 7 | hasaki
# Processing Record 21 of Set 7 | villarrica
# Processing Record 22 of Set 7 | thinadhoo
# Processing Record 23 of Set 7 | atasu
# Processing Record 24 of Set 7 | huazolotitlan
# City not found. Skipping...
# Processing Record 25 of Set 7 | sembe
# Processing Record 26 of Set 7 | dakar
# Processing Record 27 of Set 7 | clonakilty
# Processing Record 28 of Set 7 | touros
# Processing Record 29 of Set 7 | zhigansk
# Processing Record 30 of Set 7 | constitucion
# Processing Record 31 of Set 7 | zigong
# Processing Record 32 of Set 7 | airai
# Processing Record 33 of Set 7 | hashtgerd
# Processing Record 34 of Set 7 | tommot
# Processing Record 35 of Set 7 | mount gambier
# Processing Record 36 of Set 7 | porbandar
# Processing Record 37 of Set 7 | svetlogorsk
# Processing Record 38 of Set 7 | saint anthony
# Processing Record 39 of Set 7 | talcahuano
# Processing Record 40 of Set 7 | noumea
# Processing Record 41 of Set 7 | puerto del rosario
# Processing Record 42 of Set 7 | matagami
# Processing Record 43 of Set 7 | alice springs
# Processing Record 44 of Set 7 | rodrigues alves
# Processing Record 45 of Set 7 | eloi mendes
# Processing Record 46 of Set 7 | gravdal
# Processing Record 47 of Set 7 | saint-pierre
# Processing Record 48 of Set 7 | saint-philippe
# Processing Record 49 of Set 7 | daru
# Processing Record 50 of Set 7 | peleduy
# Processing Record 1 of Set 8 | sorkjosen
# Processing Record 2 of Set 8 | penalva
# Processing Record 3 of Set 8 | namibe
# Processing Record 4 of Set 8 | sal rei
# Processing Record 5 of Set 8 | san patricio
# Processing Record 6 of Set 8 | kawalu
# Processing Record 7 of Set 8 | kupang
# Processing Record 8 of Set 8 | tirat karmel
# Processing Record 9 of Set 8 | adrar
# Processing Record 10 of Set 8 | hami
# Processing Record 11 of Set 8 | hervey bay
# Processing Record 12 of Set 8 | hendijan
# City not found. Skipping...
# Processing Record 13 of Set 8 | mbacke
# City not found. Skipping...
# Processing Record 14 of Set 8 | shaki
# Processing Record 15 of Set 8 | cabangahan
# Processing Record 16 of Set 8 | kloulklubed
# Processing Record 17 of Set 8 | kytlym
# City not found. Skipping...
# Processing Record 18 of Set 8 | nganjuk
# Processing Record 19 of Set 8 | tomohon
# Processing Record 20 of Set 8 | luyang
# Processing Record 21 of Set 8 | paralimni
# Processing Record 22 of Set 8 | norman wells
# Processing Record 23 of Set 8 | bowen
# Processing Record 24 of Set 8 | atambua
# Processing Record 25 of Set 8 | overyata
# Processing Record 26 of Set 8 | feijo
# Processing Record 27 of Set 8 | quang ngai
# Processing Record 28 of Set 8 | mercedes
# Processing Record 29 of Set 8 | meulaboh
# Processing Record 30 of Set 8 | emerald
# Processing Record 31 of Set 8 | kamenskoye
# City not found. Skipping...
# Processing Record 32 of Set 8 | muros
# Processing Record 33 of Set 8 | jacksonville
# Processing Record 34 of Set 8 | edd
# Processing Record 35 of Set 8 | aktash
# Processing Record 36 of Set 8 | tahe
# Processing Record 37 of Set 8 | hassleholm
# Processing Record 38 of Set 8 | la ronge
# Processing Record 39 of Set 8 | rio branco
# Processing Record 40 of Set 8 | beroroha
# Processing Record 41 of Set 8 | luba
# Processing Record 42 of Set 8 | zhuhai
# Processing Record 43 of Set 8 | tungor
# Processing Record 44 of Set 8 | asyut
# Processing Record 45 of Set 8 | lompoc
# Processing Record 46 of Set 8 | coihaique
# Processing Record 47 of Set 8 | baykit
# Processing Record 48 of Set 8 | yubari
# Processing Record 49 of Set 8 | thunder bay
# Processing Record 50 of Set 8 | pontal do parana
# Processing Record 1 of Set 9 | ossora
# Processing Record 2 of Set 9 | biskamzha
# Processing Record 3 of Set 9 | achit
# Processing Record 4 of Set 9 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 5 of Set 9 | lodja
# Processing Record 6 of Set 9 | alakurtti
# Processing Record 7 of Set 9 | crab hill
# City not found. Skipping...
# Processing Record 8 of Set 9 | ilave
# Processing Record 9 of Set 9 | toliary
# City not found. Skipping...
# Processing Record 10 of Set 9 | empalme
# Processing Record 11 of Set 9 | aykhal
# Processing Record 12 of Set 9 | fort madison
# Processing Record 13 of Set 9 | aklavik
# Processing Record 14 of Set 9 | brigantine
# Processing Record 15 of Set 9 | quartucciu
# Processing Record 16 of Set 9 | mys shmidta
# City not found. Skipping...
# Processing Record 17 of Set 9 | tulu bolo
# Processing Record 18 of Set 9 | grenada
# Processing Record 19 of Set 9 | qarayeri
# Processing Record 20 of Set 9 | severo-yeniseyskiy
# Processing Record 21 of Set 9 | praia
# Processing Record 22 of Set 9 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 23 of Set 9 | hovd
# Processing Record 24 of Set 9 | mahebourg
# Processing Record 25 of Set 9 | omboue
# Processing Record 26 of Set 9 | wang saphung
# Processing Record 27 of Set 9 | nizhneyansk
# City not found. Skipping...
# Processing Record 28 of Set 9 | yamoussoukro
# Processing Record 29 of Set 9 | zonalnoye
# City not found. Skipping...
# Processing Record 30 of Set 9 | luan
# Processing Record 31 of Set 9 | jibuti
# Processing Record 32 of Set 9 | freeport
# Processing Record 33 of Set 9 | kargat
# Processing Record 34 of Set 9 | orlik
# Processing Record 35 of Set 9 | garden city
# Processing Record 36 of Set 9 | daxian
# City not found. Skipping...
# Processing Record 37 of Set 9 | nashville
# Processing Record 38 of Set 9 | sokolo
# Processing Record 39 of Set 9 | francisco sa
# Processing Record 40 of Set 9 | high level
# Processing Record 41 of Set 9 | sao filipe
# Processing Record 42 of Set 9 | nemuro
# Processing Record 43 of Set 9 | slave lake
# Processing Record 44 of Set 9 | shimoda
# Processing Record 45 of Set 9 | mayo
# Processing Record 46 of Set 9 | green river
# Processing Record 47 of Set 9 | hurghada
# Processing Record 48 of Set 9 | kieta
# Processing Record 49 of Set 9 | chernigovka
# Processing Record 50 of Set 9 | geraldton
# Processing Record 1 of Set 10 | lima
# Processing Record 2 of Set 10 | kuche
# City not found. Skipping...
# Processing Record 3 of Set 10 | amot
# Processing Record 4 of Set 10 | zhuzhou
# Processing Record 5 of Set 10 | moranbah
# Processing Record 6 of Set 10 | sao joao da barra
# Processing Record 7 of Set 10 | lakes entrance
# Processing Record 8 of Set 10 | mount darwin
# Processing Record 9 of Set 10 | saint-francois
# Processing Record 10 of Set 10 | pemangkat
# Processing Record 11 of Set 10 | chapais
# Processing Record 12 of Set 10 | diamantino
# Processing Record 13 of Set 10 | pitkyaranta
# Processing Record 14 of Set 10 | harper
# Processing Record 15 of Set 10 | burica
# City not found. Skipping...
# Processing Record 16 of Set 10 | port hardy
# Processing Record 17 of Set 10 | salalah
# Processing Record 18 of Set 10 | shirgaon
# Processing Record 19 of Set 10 | hinton
# Processing Record 20 of Set 10 | kemijarvi
# Processing Record 21 of Set 10 | pontes e lacerda
# Processing Record 22 of Set 10 | finsterwalde
# Processing Record 23 of Set 10 | jumla
# Processing Record 24 of Set 10 | lamar
# Processing Record 25 of Set 10 | suhbaatar
# Processing Record 26 of Set 10 | cacoal
# Processing Record 27 of Set 10 | calatayud
# Processing Record 28 of Set 10 | nagold
# Processing Record 29 of Set 10 | goba
# Processing Record 30 of Set 10 | riachao das neves
# Processing Record 31 of Set 10 | shunyi
# Processing Record 32 of Set 10 | xghajra
# City not found. Skipping...
# Processing Record 33 of Set 10 | vallenar
# Processing Record 34 of Set 10 | patan
# Processing Record 35 of Set 10 | manicore
# Processing Record 36 of Set 10 | nuevo progreso
# Processing Record 37 of Set 10 | craig
# Processing Record 38 of Set 10 | mizpe ramon
# City not found. Skipping...
# Processing Record 39 of Set 10 | sioux lookout
# Processing Record 40 of Set 10 | kralendijk
# Processing Record 41 of Set 10 | sawakin
# Processing Record 42 of Set 10 | bambous virieux
# Processing Record 43 of Set 10 | isabela
# Processing Record 44 of Set 10 | makinsk
# Processing Record 45 of Set 10 | urgut
# Processing Record 46 of Set 10 | tsiroanomandidy
# Processing Record 47 of Set 10 | nortelandia
# Processing Record 48 of Set 10 | mweka
# Processing Record 49 of Set 10 | krasnyy yar
# Processing Record 50 of Set 10 | huarmey
# Processing Record 1 of Set 11 | salinopolis
# Processing Record 2 of Set 11 | luwuk
# Processing Record 3 of Set 11 | camden
# Processing Record 4 of Set 11 | santa isabel do rio negro
# Processing Record 5 of Set 11 | bukachacha
# Processing Record 6 of Set 11 | santa cruz de rosales
# City not found. Skipping...
# Processing Record 7 of Set 11 | pillaro
# Processing Record 8 of Set 11 | labutta
# City not found. Skipping...
# Processing Record 9 of Set 11 | mocambique
# City not found. Skipping...
# Processing Record 10 of Set 11 | chino valley
# Processing Record 11 of Set 11 | sungurlu
# Processing Record 12 of Set 11 | sibu
# Processing Record 13 of Set 11 | ormara
# Processing Record 14 of Set 11 | alibag
# Processing Record 15 of Set 11 | togur
# Processing Record 16 of Set 11 | biloela
# Processing Record 17 of Set 11 | along
# Processing Record 18 of Set 11 | mafinga
# Processing Record 19 of Set 11 | itoman
# Processing Record 20 of Set 11 | nanakuli
# Processing Record 21 of Set 11 | egvekinot
# Processing Record 22 of Set 11 | nhulunbuy
# Processing Record 23 of Set 11 | lixourion
# Processing Record 24 of Set 11 | srednekolymsk
# Processing Record 25 of Set 11 | innisfail
# Processing Record 26 of Set 11 | margate
# Processing Record 27 of Set 11 | alofi
# Processing Record 28 of Set 11 | taicheng
# Processing Record 29 of Set 11 | highland springs
# Processing Record 30 of Set 11 | cutervo
# Processing Record 31 of Set 11 | aranjuez
# Processing Record 32 of Set 11 | belyy yar
# Processing Record 33 of Set 11 | kamenka
# Processing Record 34 of Set 11 | ketchikan
# Processing Record 35 of Set 11 | mehamn
# Processing Record 36 of Set 11 | vidim
# Processing Record 37 of Set 11 | bonfim
# Processing Record 38 of Set 11 | narsaq
# Processing Record 39 of Set 11 | camopi
# Processing Record 40 of Set 11 | letlhakeng
# Processing Record 41 of Set 11 | cardenas
# Processing Record 42 of Set 11 | nagutskoye
# Processing Record 43 of Set 11 | ogbomosho
# Processing Record 44 of Set 11 | aden
# Processing Record 45 of Set 11 | road town
# Processing Record 46 of Set 11 | makakilo city
# Processing Record 47 of Set 11 | turukhansk
# Processing Record 48 of Set 11 | lashio
# Processing Record 49 of Set 11 | labuhan
# Processing Record 50 of Set 11 | jiangyou
# Processing Record 1 of Set 12 | gijon
# Processing Record 2 of Set 12 | antsohihy
# Processing Record 3 of Set 12 | haibowan
# City not found. Skipping...
# Processing Record 4 of Set 12 | klaksvik
# Processing Record 5 of Set 12 | el dorado
# Processing Record 6 of Set 12 | sabang
# Processing Record 7 of Set 12 | naliya
# Processing Record 8 of Set 12 | kindu
# Processing Record 9 of Set 12 | maceio
# Processing Record 10 of Set 12 | anupgarh
# Processing Record 11 of Set 12 | sisimiut
# Processing Record 12 of Set 12 | lesnoy
# Processing Record 13 of Set 12 | kargasok
# Processing Record 14 of Set 12 | paamiut
# Processing Record 15 of Set 12 | rocha
# Processing Record 16 of Set 12 | kampene
# Processing Record 17 of Set 12 | buariki
# City not found. Skipping...
# Processing Record 18 of Set 12 | geresk
# City not found. Skipping...
# Processing Record 19 of Set 12 | estacion coahuila
# Processing Record 20 of Set 12 | tefe
# Processing Record 21 of Set 12 | karpathos
# Processing Record 22 of Set 12 | nipawin
# Processing Record 23 of Set 12 | yeppoon
# Processing Record 24 of Set 12 | noyabrsk
# Processing Record 25 of Set 12 | pousat
# City not found. Skipping...
# Processing Record 26 of Set 12 | parati
# Processing Record 27 of Set 12 | warrnambool
# Processing Record 28 of Set 12 | florence
# Processing Record 29 of Set 12 | macusani
# Processing Record 30 of Set 12 | olinda
# Processing Record 31 of Set 12 | taoudenni
# Processing Record 32 of Set 12 | pinheiro machado
# Processing Record 33 of Set 12 | yulara
# Processing Record 34 of Set 12 | black river
# Processing Record 35 of Set 12 | coxim
# Processing Record 36 of Set 12 | san blas
# Processing Record 37 of Set 12 | chernyshevsk
# Processing Record 38 of Set 12 | katha
# City not found. Skipping...
# Processing Record 39 of Set 12 | jalu
# Processing Record 40 of Set 12 | dingle
# Processing Record 41 of Set 12 | wasilla
# Processing Record 42 of Set 12 | dalton
# Processing Record 43 of Set 12 | imbituba
# Processing Record 44 of Set 12 | ajaccio
# Processing Record 45 of Set 12 | siavonga
# Processing Record 46 of Set 12 | bagan
# Processing Record 47 of Set 12 | fort wellington
# Processing Record 48 of Set 12 | west helena
# Processing Record 49 of Set 12 | arlit
# Processing Record 50 of Set 12 | grand gaube
# Processing Record 1 of Set 13 | boulder
# Processing Record 2 of Set 13 | nsanje
# Processing Record 3 of Set 13 | warwick
# Processing Record 4 of Set 13 | solwezi
# Processing Record 5 of Set 13 | santa vitoria do palmar
# Processing Record 6 of Set 13 | ndele
# Processing Record 7 of Set 13 | tovarkovo
# Processing Record 8 of Set 13 | vestmanna
# Processing Record 9 of Set 13 | batsfjord
# Processing Record 10 of Set 13 | chardara
# Processing Record 11 of Set 13 | solok
# Processing Record 12 of Set 13 | kyra
# Processing Record 13 of Set 13 | cabedelo
# Processing Record 14 of Set 13 | conde
# Processing Record 15 of Set 13 | rawannawi
# City not found. Skipping...
# Processing Record 16 of Set 13 | mizan teferi
# Processing Record 17 of Set 13 | ujjain
# Processing Record 18 of Set 13 | sept-iles
# Processing Record 19 of Set 13 | montreal
# Processing Record 20 of Set 13 | broome
# Processing Record 21 of Set 13 | aguada de pasajeros
# Processing Record 22 of Set 13 | mullaitivu
# City not found. Skipping...
# Processing Record 23 of Set 13 | poum
# Processing Record 24 of Set 13 | zhanakorgan
# Processing Record 25 of Set 13 | zeya
# Processing Record 26 of Set 13 | san juan nepomuceno
# Processing Record 27 of Set 13 | lorengau
# Processing Record 28 of Set 13 | hambantota
# Processing Record 29 of Set 13 | khonsa
# Processing Record 30 of Set 13 | tocopilla
# Processing Record 31 of Set 13 | udimskiy
# Processing Record 32 of Set 13 | nara
# Processing Record 33 of Set 13 | ptuj
# Processing Record 34 of Set 13 | houma
# Processing Record 35 of Set 13 | victor harbor
# Processing Record 36 of Set 13 | camacupa
# Processing Record 37 of Set 13 | monrovia
# Processing Record 38 of Set 13 | kiama
# Processing Record 39 of Set 13 | pachino
# Processing Record 40 of Set 13 | barbar
# City not found. Skipping...
# Processing Record 41 of Set 13 | zhezkazgan
# Processing Record 42 of Set 13 | lahat
# Processing Record 43 of Set 13 | envira
# Processing Record 44 of Set 13 | urdzhar
# City not found. Skipping...
# Processing Record 45 of Set 13 | buriti alegre
# Processing Record 46 of Set 13 | opuwo
# Processing Record 47 of Set 13 | amboasary
# Processing Record 48 of Set 13 | porangatu
# Processing Record 49 of Set 13 | nassau
# Processing Record 50 of Set 13 | wajima
# Processing Record 1 of Set 14 | curaca
# Processing Record 2 of Set 14 | dudinka
# Processing Record 3 of Set 14 | aracruz
# Processing Record 4 of Set 14 | aksay
# Processing Record 5 of Set 14 | terrace
# Processing Record 6 of Set 14 | menemen
# Processing Record 7 of Set 14 | deer lake
# Processing Record 8 of Set 14 | dunedin
# Processing Record 9 of Set 14 | mahon
# Processing Record 10 of Set 14 | roblin
# Processing Record 11 of Set 14 | coffs harbour
# Processing Record 12 of Set 14 | naze
# Processing Record 13 of Set 14 | naica
# Processing Record 14 of Set 14 | stornoway
# Processing Record 15 of Set 14 | tchibanga
# Processing Record 16 of Set 14 | surskoye
# Processing Record 17 of Set 14 | moyale
# Processing Record 18 of Set 14 | karratha
# Processing Record 19 of Set 14 | saint-louis
# Processing Record 20 of Set 14 | padang
# Processing Record 21 of Set 14 | manzanillo
# Processing Record 22 of Set 14 | mutsamudu
# City not found. Skipping...
# Processing Record 23 of Set 14 | zheshart
# Processing Record 24 of Set 14 | ahipara
# Processing Record 25 of Set 14 | qatana
# Processing Record 26 of Set 14 | juneau
# Processing Record 27 of Set 14 | cozumel
# Processing Record 28 of Set 14 | toribio
# Processing Record 29 of Set 14 | buraydah
# Processing Record 30 of Set 14 | were ilu
# Processing Record 31 of Set 14 | tomatlan
# Processing Record 32 of Set 14 | vohibinany
# Processing Record 33 of Set 14 | rincon
# Processing Record 34 of Set 14 | louisbourg
# City not found. Skipping...
# Processing Record 35 of Set 14 | dibai
# Processing Record 36 of Set 14 | sogne
# Processing Record 37 of Set 14 | buchanan
# Processing Record 38 of Set 14 | tautira
# Processing Record 39 of Set 14 | garissa
# Processing Record 40 of Set 14 | mabay
# Processing Record 41 of Set 14 | pogranichnyy
# Processing Record 42 of Set 14 | haapu
# City not found. Skipping...
# Processing Record 43 of Set 14 | sarkand
# Processing Record 44 of Set 14 | vila velha
# Processing Record 45 of Set 14 | rungata
# City not found. Skipping...
# Processing Record 46 of Set 14 | ust-kuyga
# Processing Record 47 of Set 14 | mathathane
# Processing Record 48 of Set 14 | ostersund
# Processing Record 49 of Set 14 | glubokoe
# City not found. Skipping...
# Processing Record 50 of Set 14 | manzil salim
# Processing Record 1 of Set 15 | morant bay
# Processing Record 2 of Set 15 | cheney
# Processing Record 3 of Set 15 | acapulco
# Processing Record 4 of Set 15 | sorvag
# City not found. Skipping...
# Processing Record 5 of Set 15 | bartica
# Processing Record 6 of Set 15 | makat
# Processing Record 7 of Set 15 | pacanga
# Processing Record 8 of Set 15 | batticaloa
# Processing Record 9 of Set 15 | kaoma
# Processing Record 10 of Set 15 | uusikaupunki
# Processing Record 11 of Set 15 | nanyuki
# Processing Record 12 of Set 15 | yumen
# Processing Record 13 of Set 15 | shwebo
# Processing Record 14 of Set 15 | santarem
# Processing Record 15 of Set 15 | upata
# Processing Record 16 of Set 15 | beaverlodge
# Processing Record 17 of Set 15 | la maddalena
# Processing Record 18 of Set 15 | guaruja
# Processing Record 19 of Set 15 | aksu
# Processing Record 20 of Set 15 | alenquer
# Processing Record 21 of Set 15 | burnie
# Processing Record 22 of Set 15 | gamba
# Processing Record 23 of Set 15 | bairnsdale
# Processing Record 24 of Set 15 | cordele
# Processing Record 25 of Set 15 | kiunga
# Processing Record 26 of Set 15 | taltal
# Processing Record 27 of Set 15 | yakima
# Processing Record 28 of Set 15 | champagnole
# Processing Record 29 of Set 15 | ypsonas
# Processing Record 30 of Set 15 | sorland
# Processing Record 31 of Set 15 | karamea
# City not found. Skipping...
# Processing Record 32 of Set 15 | vila franca do campo
# Processing Record 33 of Set 15 | half moon bay
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
WeatherPy_Database = pd.DataFrame(city_data)
WeatherPy_Database.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Norrtalje      SE  59.7580   18.7050     66.02        86          27
# 1       Rikitea      PF -23.1203 -134.9692     73.56        76           0
# 2      Cherskiy      RU  68.7500  161.3000     47.80        39           8
# 3        Laguna      US  38.4210 -121.4238    106.32        18           0
# 4       Ushuaia      AR -54.8000  -68.3000     29.86        93         100
# 5          Hilo      US  19.7297 -155.0900     84.27        85          41
# 6   Santa Maria      BR -29.6842  -53.8069     58.30       100           0
# 7       Mataura      NZ -46.1927  168.8643     44.47        78         100
# 8  Longyearbyen      SJ  78.2186   15.6401     51.64        82          40
# 9   Clyde River      CA  70.4692  -68.5914     35.83       100         100
#
#    Wind Speed       Description                 Date
# 0        5.32  scattered clouds  2022-07-21 01:24:59
# 1        5.61        light rain  2022-07-21 01:23:12
# 2       18.19         clear sky  2022-07-21 01:24:59
# 3       13.80         clear sky  2022-07-21 01:15:36
# 4       17.27              snow  2022-07-21 01:25:00
# 5        5.01  scattered clouds  2022-07-21 01:13:57
# 6        1.14         clear sky  2022-07-21 01:25:00
# 7        4.00   overcast clouds  2022-07-21 01:16:51
# 8       11.50  scattered clouds  2022-07-21 01:16:53
# 9        9.22        light rain  2022-07-21 01:13:11

# %%
output_data_file = "WeatherPy_Database.csv"
WeatherPy_Database.to_csv(output_data_file, index_label="City_ID")
